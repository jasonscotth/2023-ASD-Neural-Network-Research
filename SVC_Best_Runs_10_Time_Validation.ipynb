# %% [markdown]
# Testing on 10 time cross validation averaging completed by Scott Hartsell

# %%
#resets all local variables when rerunning code
# %reset -f

# %%
# !pip install nilearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.6 MB 46.2 MB/s
# ...

# %%
# filters out warnings generated by interpreter
import warnings
warnings.filterwarnings("ignore")

# %%
#using nilearn Python library, ABIDE data set
#https://nilearn.github.io/modules/reference.html
from nilearn.datasets import fetch_abide_pcp

#using CC400 parcellation method w/ CPAC preprocessing -> reduce noise and artifacts
#https://nilearn.github.io/modules/generated/nilearn.datasets.fetch_abide_pcp.html#nilearn.datasets.fetch_abide_pcp
abide = fetch_abide_pcp(derivatives = ['rois_cc400'], pipeline = 'cpac', quality_checked = True)

#phenotypic data is the affected group, 'autistic'
y = abide.phenotypic['DX_GROUP']

#if y is equal to 2, set to 0 -> so that output is binary 0 (autistic) or 1 (normal)
y[y == 2] = 0

# y is left as a vector of labels for the data on how each is diagnosed

#defining brain atlas used for parcellation 'CC400'
atlas = 'CC400'
# Out:
# Dataset created in /root/nilearn_data/ABIDE_pcp
#
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...
#  ...done. (0 seconds, 0 min)
# ...

# %%
#Science Kit Learn -> a Python machine learning library
#https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
#"Make a scorer from a performance metric or loss function."
from sklearn.metrics import make_scorer

#accuracy classification score, "compute the recall"
from sklearn.metrics import accuracy_score, recall_score

#dictionary, 'accuracy' -> key, function call stored
scoring = {
    'accuracy':    make_scorer(accuracy_score),
    'sensitivity': make_scorer(recall_score),
    'specificity': make_scorer(recall_score,pos_label=0)
}

# %%
#declaring string variables
correlation = 'correlation'
ksvm = "kSVM"

# %%
# Kernel SVM (Support Vector Machines)
# SVC stands for C-Support Vector Classification
from sklearn.svm import SVC

#order of execution
#1st
rbf_auto_100 = SVC(kernel = 'rbf', gamma = 'auto', C = 100)

#2nd
sigmoid_auto_100 = SVC(kernel = 'sigmoid', gamma = 'auto', C = 100)

#3rd
poly_auto_1000 = SVC(kernel = 'poly', gamma = 'auto', C = 1000)

#4th
rbf_scale_10 = SVC(kernel = 'rbf', gamma = 'scale', C = 10)

#5th
sigmoid_scale_1 = SVC(kernel = 'sigmoid', gamma = 'scale', C = 1)

#6th
poly_scale_10 = SVC(kernel = 'poly', gamma = 'scale', C = 10)

# %%
#partition data into 5 sections w/ random elements
#random_state determines seed, 'None' is default and indicates no seed.
#an integer can be passed to get reproducable results
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = None)

# %%
import numpy as np

# %%
from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

# %% [markdown]
# rbf_auto_100

# %%
conn_est = ConnectivityMeasure(kind = "correlation")
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

from sklearn.model_selection import cross_validate
scores = cross_validate(rbf_auto_100, X, y, cv = skf,
                        scoring = scoring,
                        return_train_score=True)

# %%
ksvm_corr_acc = "{:.2%}".format(round(np.mean(scores['test_accuracy']),4))
ksvm_corr_sen = "{:.2%}".format(round(np.mean(scores['test_sensitivity']),4))
ksvm_corr_spe = "{:.2%}".format(round(np.mean(scores['test_specificity']),4))

# %%
# #############################################################################
# ROC analysis

path = 'C:\\Users\\xyang\\Desktop\\research\\PytorchStudy\\results\\'
import matplotlib.pyplot as plt

from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve

# Run classifier with cross-validation and plot ROC curves
#cv = StratifiedKFold(n_splits = 5)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()
for i, (train, test) in enumerate(skf.split(X, y)):
    rbf_auto_100.fit(X[train], y[train])
    viz = plot_roc_curve(rbf_auto_100, X[test], y[test],
                          name='ROC fold {}'.format(i),
                          alpha=0.3, lw=1, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
        lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                label=r'$\pm$ 1 std. dev.')

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
        title= "Model: " + str(ksvm) + "   Atlas: "+ str(atlas) + "   Kind: " + str(correlation))
ax.legend(loc="lower right")
plt.savefig(str(path) + str(ksvm) + '_' + str(atlas) + '_' + str(correlation) + '.png')
plt.show()

# %%
from IPython.display import HTML, display

test=[["","","Correlation",""],

      ["Classifier","Sensitivity","Specificity", "Accuracy"],
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc],
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ...
# <table><tr><td></td><td></td><td>Correlation</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>kSVM</td><td>61.30%</td><td>71.37%</td><td>66.70%</td></tr></table>

# %% [markdown]
# sigmoid_auto_100

# %%
conn_est = ConnectivityMeasure(kind = "correlation")
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

from sklearn.model_selection import cross_validate
scores = cross_validate(sigmoid_auto_100, X, y, cv = skf,
                        scoring = scoring,
                        return_train_score=True)

# %%
ksvm_corr_acc = "{:.2%}".format(round(np.mean(scores['test_accuracy']),4))
ksvm_corr_sen = "{:.2%}".format(round(np.mean(scores['test_sensitivity']),4))
ksvm_corr_spe = "{:.2%}".format(round(np.mean(scores['test_specificity']),4))

# %%
# #############################################################################
# ROC analysis

path = 'C:\\Users\\xyang\\Desktop\\research\\PytorchStudy\\results\\'
import matplotlib.pyplot as plt

from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve

# Run classifier with cross-validation and plot ROC curves
#cv = StratifiedKFold(n_splits = 5)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()
for i, (train, test) in enumerate(skf.split(X, y)):
    sigmoid_auto_100.fit(X[train], y[train])
    viz = plot_roc_curve(sigmoid_auto_100, X[test], y[test],
                          name='ROC fold {}'.format(i),
                          alpha=0.3, lw=1, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
        lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                label=r'$\pm$ 1 std. dev.')

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
        title= "Model: " + str(ksvm) + "   Atlas: "+ str(atlas) + "   Kind: " + str(correlation))
ax.legend(loc="lower right")
plt.savefig(str(path) + str(ksvm) + '_' + str(atlas) + '_' + str(correlation) + '.png')
plt.show()

# %%
from IPython.display import HTML, display

test=[["","","Correlation",""],

      ["Classifier","Sensitivity","Specificity", "Accuracy"],
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc],
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ...
# <table><tr><td></td><td></td><td>Correlation</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>kSVM</td><td>61.53%</td><td>73.93%</td><td>68.19%</td></tr></table>

# %% [markdown]
# poly_auto_1000

# %%
conn_est = ConnectivityMeasure(kind = "correlation")
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

from sklearn.model_selection import cross_validate
scores = cross_validate(poly_auto_1000, X, y, cv = skf,
                        scoring = scoring,
                        return_train_score=True)

# %%
ksvm_corr_acc = "{:.2%}".format(round(np.mean(scores['test_accuracy']),4))
ksvm_corr_sen = "{:.2%}".format(round(np.mean(scores['test_sensitivity']),4))
ksvm_corr_spe = "{:.2%}".format(round(np.mean(scores['test_specificity']),4))

# %%
# #############################################################################
# ROC analysis

path = 'C:\\Users\\xyang\\Desktop\\research\\PytorchStudy\\results\\'
import matplotlib.pyplot as plt

from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve

# Run classifier with cross-validation and plot ROC curves
#cv = StratifiedKFold(n_splits = 5)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()
for i, (train, test) in enumerate(skf.split(X, y)):
    poly_auto_1000.fit(X[train], y[train])
    viz = plot_roc_curve(poly_auto_1000, X[test], y[test],
                          name='ROC fold {}'.format(i),
                          alpha=0.3, lw=1, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
        lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                label=r'$\pm$ 1 std. dev.')

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
        title= "Model: " + str(ksvm) + "   Atlas: "+ str(atlas) + "   Kind: " + str(correlation))
ax.legend(loc="lower right")
plt.savefig(str(path) + str(ksvm) + '_' + str(atlas) + '_' + str(correlation) + '.png')
plt.show()

# %%
from IPython.display import HTML, display

test=[["","","Correlation",""],

      ["Classifier","Sensitivity","Specificity", "Accuracy"],
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc],
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ...
# <table><tr><td></td><td></td><td>Correlation</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>kSVM</td><td>2.48%</td><td>96.78%</td><td>53.16%</td></tr></table>

# %% [markdown]
# rbf_scale_10

# %%
conn_est = ConnectivityMeasure(kind = "correlation")
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

from sklearn.model_selection import cross_validate
scores = cross_validate(rbf_scale_10, X, y, cv = skf,
                        scoring = scoring,
                        return_train_score=True)

# %%
ksvm_corr_acc = "{:.2%}".format(round(np.mean(scores['test_accuracy']),4))
ksvm_corr_sen = "{:.2%}".format(round(np.mean(scores['test_sensitivity']),4))
ksvm_corr_spe = "{:.2%}".format(round(np.mean(scores['test_specificity']),4))

# %%
# #############################################################################
# ROC analysis

path = 'C:\\Users\\xyang\\Desktop\\research\\PytorchStudy\\results\\'
import matplotlib.pyplot as plt

from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve

# Run classifier with cross-validation and plot ROC curves
#cv = StratifiedKFold(n_splits = 5)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()
for i, (train, test) in enumerate(skf.split(X, y)):
    rbf_scale_10.fit(X[train], y[train])
    viz = plot_roc_curve(rbf_scale_10, X[test], y[test],
                          name='ROC fold {}'.format(i),
                          alpha=0.3, lw=1, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
        lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                label=r'$\pm$ 1 std. dev.')

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
        title= "Model: " + str(ksvm) + "   Atlas: "+ str(atlas) + "   Kind: " + str(correlation))
ax.legend(loc="lower right")
plt.savefig(str(path) + str(ksvm) + '_' + str(atlas) + '_' + str(correlation) + '.png')
plt.show()

# %%
from IPython.display import HTML, display

test=[["","","Correlation",""],

      ["Classifier","Sensitivity","Specificity", "Accuracy"],
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc],
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ...
# <table><tr><td></td><td></td><td>Correlation</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>kSVM</td><td>62.04%</td><td>76.29%</td><td>69.69%</td></tr></table>

# %% [markdown]
# sigmoid_scale_1

# %%
conn_est = ConnectivityMeasure(kind = "correlation")
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

from sklearn.model_selection import cross_validate
scores = cross_validate(sigmoid_scale_1, X, y, cv = skf,
                        scoring = scoring,
                        return_train_score=True)

# %%
ksvm_corr_acc = "{:.2%}".format(round(np.mean(scores['test_accuracy']),4))
ksvm_corr_sen = "{:.2%}".format(round(np.mean(scores['test_sensitivity']),4))
ksvm_corr_spe = "{:.2%}".format(round(np.mean(scores['test_specificity']),4))

# %%
# #############################################################################
# ROC analysis

path = 'C:\\Users\\xyang\\Desktop\\research\\PytorchStudy\\results\\'
import matplotlib.pyplot as plt

from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve

# Run classifier with cross-validation and plot ROC curves
#cv = StratifiedKFold(n_splits = 5)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()
for i, (train, test) in enumerate(skf.split(X, y)):
    sigmoid_scale_1.fit(X[train], y[train])
    viz = plot_roc_curve(sigmoid_scale_1, X[test], y[test],
                          name='ROC fold {}'.format(i),
                          alpha=0.3, lw=1, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
        lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                label=r'$\pm$ 1 std. dev.')

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
        title= "Model: " + str(ksvm) + "   Atlas: "+ str(atlas) + "   Kind: " + str(correlation))
ax.legend(loc="lower right")
plt.savefig(str(path) + str(ksvm) + '_' + str(atlas) + '_' + str(correlation) + '.png')
plt.show()

# %%
from IPython.display import HTML, display

test=[["","","Correlation",""],

      ["Classifier","Sensitivity","Specificity", "Accuracy"],
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc],
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ...
# <table><tr><td></td><td></td><td>Correlation</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>kSVM</td><td>48.63%</td><td>56.40%</td><td>52.81%</td></tr></table>

# %% [markdown]
# poly_scale_10

# %%
conn_est = ConnectivityMeasure(kind = "correlation")
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

from sklearn.model_selection import cross_validate
scores = cross_validate(poly_scale_10, X, y, cv = skf,
                        scoring = scoring,
                        return_train_score=True)

# %%
ksvm_corr_acc = "{:.2%}".format(round(np.mean(scores['test_accuracy']),4))
ksvm_corr_sen = "{:.2%}".format(round(np.mean(scores['test_sensitivity']),4))
ksvm_corr_spe = "{:.2%}".format(round(np.mean(scores['test_specificity']),4))

# %%
# #############################################################################
# ROC analysis

path = 'C:\\Users\\xyang\\Desktop\\research\\PytorchStudy\\results\\'
import matplotlib.pyplot as plt

from sklearn.metrics import auc
from sklearn.metrics import plot_roc_curve

# Run classifier with cross-validation and plot ROC curves
#cv = StratifiedKFold(n_splits = 5)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()
for i, (train, test) in enumerate(skf.split(X, y)):
    poly_scale_10.fit(X[train], y[train])
    viz = plot_roc_curve(poly_scale_10, X[test], y[test],
                          name='ROC fold {}'.format(i),
                          alpha=0.3, lw=1, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
        lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                label=r'$\pm$ 1 std. dev.')

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
        title= "Model: " + str(ksvm) + "   Atlas: "+ str(atlas) + "   Kind: " + str(correlation))
ax.legend(loc="lower right")
plt.savefig(str(path) + str(ksvm) + '_' + str(atlas) + '_' + str(correlation) + '.png')
plt.show()

# %%
from IPython.display import HTML, display

test=[["","","Correlation",""],

      ["Classifier","Sensitivity","Specificity", "Accuracy"],
      ["kSVM",ksvm_corr_sen,ksvm_corr_spe,ksvm_corr_acc],
     ]

print("Test:")
print("===========================================================================================")
display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in test))
))
# Out:
# Test:
# ...
# <table><tr><td></td><td></td><td>Correlation</td><td></td></tr><tr><td>Classifier</td><td>Sensitivity</td><td>Specificity</td><td>Accuracy</td></tr><tr><td>kSVM</td><td>63.51%</td><td>73.07%</td><td>68.65%</td></tr></table>
